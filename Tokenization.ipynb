# %% [markdown]
# ### GPT Tokenizer live

# %% [markdown]
# [Tiktoken](https://tiktokenizer.vercel.app/)

# %%
import tiktoken
import collections, re
import pprint as pp

# %%
enc = tiktoken.get_encoding("cl100k_base")

# %%
vocab = enc.token_byte_values()

# %%
# for v in vocab:
#     print(v.decode('utf-8', errors='ignore'))

# %% [markdown]
# ### BPE by [Sennrich et al., 2016](https://arxiv.org/abs/1508.07909)

# %%
def get_stats(vocab):
    pairs = collections.defaultdict(int)
    for word, freq in vocab.items():
        symbols = word.split()
        for i in range(len(symbols)-1):
            pairs[symbols[i],symbols[i+1]] += freq
    return pairs


def merge_vocab(pair, v_in):
    v_out = {}
    bigram = re.escape(' '.join(pair))
    p = re.compile(r'(?<!\S)' + bigram + r'(?!\S)')
    for word in v_in:
        w_out = p.sub(''.join(pair), word)
        v_out[w_out] = v_in[word]
    return v_out

# %%
vocab = {'l o w </w>' : 5, 'l o w e r </w>' : 2, 'n e w e s t </w>':6, 'w i d e s t </w>':3}
num_merges = 10

# %%
for i in range(num_merges):
    pairs = get_stats(vocab)
    print(f'pairs before megre {i+1}: {pp.pformat(pairs)}', '\n')
    best = max(pairs, key=pairs.get)
    vocab = merge_vocab(best, vocab)
    print(f'pairs after megre {i+1}: {pp.pformat(get_stats(vocab))}', '\n')
    print(f'vocab after megre {i+1}: {pp.pformat(vocab)}', '\n')
# Out:
# pairs before megre 1: defaultdict(<class 'int'>,
#             {('d', 'e'): 3,
#              ('e', 'r'): 2,
#              ('e', 's'): 9,
#              ('e', 'w'): 6,
#              ('i', 'd'): 3,
#              ('l', 'o'): 7,
#              ('n', 'e'): 6,
#              ('o', 'w'): 7,
#              ('r', '</w>'): 2,
#              ('s', 't'): 9,
#              ('t', '</w>'): 9,
#              ('w', '</w>'): 5,
#              ('w', 'e'): 8,
#              ('w', 'i'): 3})
#
# pairs after megre 1: defaultdict(<class 'int'>,
#             {('d', 'es'): 3,
#              ('e', 'r'): 2,
#              ('e', 'w'): 6,
#              ('es', 't'): 9,
#              ('i', 'd'): 3,
#              ('l', 'o'): 7,
#              ('n', 'e'): 6,
#              ('o', 'w'): 7,
#              ('r', '</w>'): 2,
#              ('t', '</w>'): 9,
#              ('w', '</w>'): 5,
#              ('w', 'e'): 2,
#              ('w', 'es'): 6,
#              ('w', 'i'): 3})
#
# vocab after megre 1: {'l o w </w>': 5,
#  'l o w e r </w>': 2,
#  'n e w es t </w>': 6,
#  'w i d es t </w>': 3}
#
# pairs before megre 2: defaultdict(<class 'int'>,
#             {('d', 'es'): 3,
#              ('e', 'r'): 2,
#              ('e', 'w'): 6,
#              ('es', 't'): 9,
#              ('i', 'd'): 3,
#              ('l', 'o'): 7,
#              ('n', 'e'): 6,
#              ('o', 'w'): 7,
#              ('r', '</w>'): 2,
#              ('t', '</w>'): 9,
#              ('w', '</w>'): 5,
#              ('w', 'e'): 2,
#              ('w', 'es'): 6,
#              ('w', 'i'): 3})
#
# pairs after megre 2: defaultdict(<class 'int'>,
#             {('d', 'est'): 3,
#              ('e', 'r'): 2,
#              ('e', 'w'): 6,
#              ('est', '</w>'): 9,
#              ('i', 'd'): 3,
#              ('l', 'o'): 7,
#              ('n', 'e'): 6,
#              ('o', 'w'): 7,
#              ('r', '</w>'): 2,
#              ('w', '</w>'): 5,
#              ('w', 'e'): 2,
#              ('w', 'est'): 6,
#              ('w', 'i'): 3})
#
# vocab after megre 2: {'l o w </w>': 5, 'l o w e r </w>': 2, 'n e w est </w>': 6, 'w i d est </w>': 3}
#
# pairs before megre 3: defaultdict(<class 'int'>,
#             {('d', 'est'): 3,
#              ('e', 'r'): 2,
#              ('e', 'w'): 6,
#              ('est', '</w>'): 9,
#              ('i', 'd'): 3,
#              ('l', 'o'): 7,
#              ('n', 'e'): 6,
#              ('o', 'w'): 7,
#              ('r', '</w>'): 2,
#              ('w', '</w>'): 5,
#              ('w', 'e'): 2,
#              ('w', 'est'): 6,
#              ('w', 'i'): 3})
#
# pairs after megre 3: defaultdict(<class 'int'>,
#             {('d', 'est</w>'): 3,
#              ('e', 'r'): 2,
#              ('e', 'w'): 6,
#              ('i', 'd'): 3,
#              ('l', 'o'): 7,
#              ('n', 'e'): 6,
#              ('o', 'w'): 7,
#              ('r', '</w>'): 2,
#              ('w', '</w>'): 5,
#              ('w', 'e'): 2,
#              ('w', 'est</w>'): 6,
#              ('w', 'i'): 3})
#
# vocab after megre 3: {'l o w </w>': 5, 'l o w e r </w>': 2, 'n e w est</w>': 6, 'w i d est</w>': 3}
#
# pairs before megre 4: defaultdict(<class 'int'>,
#             {('d', 'est</w>'): 3,
#              ('e', 'r'): 2,
#              ('e', 'w'): 6,
#              ('i', 'd'): 3,
#              ('l', 'o'): 7,
#              ('n', 'e'): 6,
#              ('o', 'w'): 7,
#              ('r', '</w>'): 2,
#              ('w', '</w>'): 5,
#              ('w', 'e'): 2,
#              ('w', 'est</w>'): 6,
#              ('w', 'i'): 3})
#
# pairs after megre 4: defaultdict(<class 'int'>,
#             {('d', 'est</w>'): 3,
#              ('e', 'r'): 2,
#              ('e', 'w'): 6,
#              ('i', 'd'): 3,
#              ('lo', 'w'): 7,
#              ('n', 'e'): 6,
#              ('r', '</w>'): 2,
#              ('w', '</w>'): 5,
#              ('w', 'e'): 2,
#              ('w', 'est</w>'): 6,
#              ('w', 'i'): 3})
#
# vocab after megre 4: {'lo w </w>': 5, 'lo w e r </w>': 2, 'n e w est</w>': 6, 'w i d est</w>': 3}
#
# pairs before megre 5: defaultdict(<class 'int'>,
#             {('d', 'est</w>'): 3,
#              ('e', 'r'): 2,
#              ('e', 'w'): 6,
#              ('i', 'd'): 3,
#              ('lo', 'w'): 7,
#              ('n', 'e'): 6,
#              ('r', '</w>'): 2,
#              ('w', '</w>'): 5,
#              ('w', 'e'): 2,
#              ('w', 'est</w>'): 6,
#              ('w', 'i'): 3})
#
# pairs after megre 5: defaultdict(<class 'int'>,
#             {('d', 'est</w>'): 3,
#              ('e', 'r'): 2,
#              ('e', 'w'): 6,
#              ('i', 'd'): 3,
#              ('low', '</w>'): 5,
#              ('low', 'e'): 2,
#              ('n', 'e'): 6,
#              ('r', '</w>'): 2,
#              ('w', 'est</w>'): 6,
#              ('w', 'i'): 3})
#
# vocab after megre 5: {'low </w>': 5, 'low e r </w>': 2, 'n e w est</w>': 6, 'w i d est</w>': 3}
#
# pairs before megre 6: defaultdict(<class 'int'>,
#             {('d', 'est</w>'): 3,
#              ('e', 'r'): 2,
#              ('e', 'w'): 6,
#              ('i', 'd'): 3,
#              ('low', '</w>'): 5,
#              ('low', 'e'): 2,
#              ('n', 'e'): 6,
#              ('r', '</w>'): 2,
#              ('w', 'est</w>'): 6,
#              ('w', 'i'): 3})
#
# pairs after megre 6: defaultdict(<class 'int'>,
#             {('d', 'est</w>'): 3,
#              ('e', 'r'): 2,
#              ('i', 'd'): 3,
#              ('low', '</w>'): 5,
#              ('low', 'e'): 2,
#              ('ne', 'w'): 6,
#              ('r', '</w>'): 2,
#              ('w', 'est</w>'): 6,
#              ('w', 'i'): 3})
#
# vocab after megre 6: {'low </w>': 5, 'low e r </w>': 2, 'ne w est</w>': 6, 'w i d est</w>': 3}
#
# pairs before megre 7: defaultdict(<class 'int'>,
#             {('d', 'est</w>'): 3,
#              ('e', 'r'): 2,
#              ('i', 'd'): 3,
#              ('low', '</w>'): 5,
#              ('low', 'e'): 2,
#              ('ne', 'w'): 6,
#              ('r', '</w>'): 2,
#              ('w', 'est</w>'): 6,
#              ('w', 'i'): 3})
#
# pairs after megre 7: defaultdict(<class 'int'>,
#             {('d', 'est</w>'): 3,
#              ('e', 'r'): 2,
#              ('i', 'd'): 3,
#              ('low', '</w>'): 5,
#              ('low', 'e'): 2,
#              ('new', 'est</w>'): 6,
#              ('r', '</w>'): 2,
#              ('w', 'i'): 3})
#
# vocab after megre 7: {'low </w>': 5, 'low e r </w>': 2, 'new est</w>': 6, 'w i d est</w>': 3}
#
# pairs before megre 8: defaultdict(<class 'int'>,
#             {('d', 'est</w>'): 3,
#              ('e', 'r'): 2,
#              ('i', 'd'): 3,
#              ('low', '</w>'): 5,
#              ('low', 'e'): 2,
#              ('new', 'est</w>'): 6,
#              ('r', '</w>'): 2,
#              ('w', 'i'): 3})
#
# pairs after megre 8: defaultdict(<class 'int'>,
#             {('d', 'est</w>'): 3,
#              ('e', 'r'): 2,
#              ('i', 'd'): 3,
#              ('low', '</w>'): 5,
#              ('low', 'e'): 2,
#              ('r', '</w>'): 2,
#              ('w', 'i'): 3})
#
# vocab after megre 8: {'low </w>': 5, 'low e r </w>': 2, 'newest</w>': 6, 'w i d est</w>': 3}
#
# pairs before megre 9: defaultdict(<class 'int'>,
#             {('d', 'est</w>'): 3,
#              ('e', 'r'): 2,
#              ('i', 'd'): 3,
#              ('low', '</w>'): 5,
#              ('low', 'e'): 2,
#              ('r', '</w>'): 2,
#              ('w', 'i'): 3})
#
# pairs after megre 9: defaultdict(<class 'int'>,
#             {('d', 'est</w>'): 3,
#              ('e', 'r'): 2,
#              ('i', 'd'): 3,
#              ('low', 'e'): 2,
#              ('r', '</w>'): 2,
#              ('w', 'i'): 3})
#
# vocab after megre 9: {'low e r </w>': 2, 'low</w>': 5, 'newest</w>': 6, 'w i d est</w>': 3}
#
# pairs before megre 10: defaultdict(<class 'int'>,
#             {('d', 'est</w>'): 3,
#              ('e', 'r'): 2,
#              ('i', 'd'): 3,
#              ('low', 'e'): 2,
#              ('r', '</w>'): 2,
#              ('w', 'i'): 3})
#
# pairs after megre 10: defaultdict(<class 'int'>,
#             {('d', 'est</w>'): 3,
#              ('e', 'r'): 2,
#              ('low', 'e'): 2,
#              ('r', '</w>'): 2,
#              ('wi', 'd'): 3})
#
# vocab after megre 10: {'low e r </w>': 2, 'low</w>': 5, 'newest</w>': 6, 'wi d est</w>': 3}
